# %%
import pandas as pd
import yfinance
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 7]

plt.rc('font', size=14)

# %%
name = 'SPY'
ticker = yfinance.Ticker(name)
df = ticker.history(interval="1d",start="2020-12-15",end="2021-04-15")

# %%
import BATrader.data as datas
df = datas.tc.get_bar_ex_eod_db('700', startday='20201215', endday='20211015')

# %%
df['Date'] = range(df.shape[0])
df = df.loc[:,['Date', 'Open', 'High', 'Low', 'Close']]

# %%
def plot_chart(df):
  fig, ax = plt.subplots()

  candlestick_ohlc(ax,df.values,width=0.6, \
                   colorup='green', colordown='red', alpha=0.8)

  fig.tight_layout()

  fig.show()

# %%
plot_chart(df)
# Out:
# <ipython-input-17-c6764406a728>:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df_ha = df.copy()

# %%
for i in range(df_ha.shape[0]):
  if i > 0:
    df_ha.loc[df_ha.index[i],'Open'] = (df['Open'][i-1] + df['Close'][i-1])/2
  
  df_ha.loc[df_ha.index[i],'Close'] = (df['Open'][i] + df['Close'][i] + df['Low'][i] +  df['High'][i])/4

df_ha = df_ha.iloc[1:,:]

# %%
plot_chart(df_ha)
# Out:
# <ipython-input-17-c6764406a728>:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
#  ### Compare with TradingView

# %% [markdown]
# <img src="./img/tv_700_heikin_ashi.png">
